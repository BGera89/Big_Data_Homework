# %% [markdown]
# # BIG DATA ANALYSIS
#
# ### Homework project
#
# #### Made by: Gergő Bolla, Edit Molnár, Anita Fekete

# %% [markdown]
# ### Task description
#
# #### Topic:
#
# The accessibility of the BME I Building with public transport.
#
# #### Data:
#
# https://openmobilitydata.org/p/bkk/42
#
# #### Data prepation and reduction
#
# The main project is understanding GTFS format
#
# #### EDA focus
#
# Basic description of the daytime public transportation, which has stops in 10 minutes walking distance from the BME I building (with pandas_profiling or Bamboolib)
#
# #### Big Data visualisation
#
# Make an interactive heatmap with Datashader based on Budapest map ( it can integrate in HoloViz), which shows the ways to the BME I building without transfer to arrive at 8 o'clock
#
# #### Analysis task
#
# Make an algorithm to find that stops with k transfer, where you can reach the BME I building in 45 minutes until 8 o'clock (k=1)

# %%
#installing important libraries for processing
# !pip install gtfs-kit
# !pip install gtfs_functions 
# !pip install datashader
# !pip install geopy
# Out:
# Requirement already satisfied: gtfs-kit in e:\games\anaconda\envs\big_data\lib\site-packages (5.2.3)
# Requirement already satisfied: requests>=2 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (2.28.1)
# Requirement already satisfied: shapely>=1 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (1.8.5.post1)
# Requirement already satisfied: folium>=0 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (0.14.0)
# Requirement already satisfied: utm>=0 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (0.7.0)
# Requirement already satisfied: json2html>=1 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (1.3.0)
# Requirement already satisfied: pycountry>=19 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (22.3.5)
# Requirement already satisfied: pandas>=1 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (1.5.2)
# Requirement already satisfied: rtree>=0 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (1.0.1)
# Requirement already satisfied: geopandas>=0 in e:\games\anaconda\envs\big_data\lib\site-packages (from gtfs-kit) (0.12.2)
# Requirement already satisfied: numpy in e:\games\anaconda\envs\big_data\lib\site-packages (from folium>=0->gtfs-kit) (1.23.5)
# Requirement already satisfied: jinja2>=2.9 in e:\games\anaconda\envs\big_data\lib\site-packages (from folium>=0->gtfs-kit) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from folium>=0->gtfs-kit) (0.6.0)
# Requirement already satisfied: packaging in e:\games\anaconda\envs\big_data\lib\site-packages (from geopandas>=0->gtfs-kit) (22.0)
# Requirement already satisfied: fiona>=1.8 in e:\games\anaconda\envs\big_data\lib\site-packages (from geopandas>=0->gtfs-kit) (1.8.22)
# Requirement already satisfied: pyproj>=2.6.1.post1 in e:\games\anaconda\envs\big_data\lib\site-packages (from geopandas>=0->gtfs-kit) (3.4.0)
# Requirement already satisfied: pytz>=2020.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas>=1->gtfs-kit) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas>=1->gtfs-kit) (2.8.2)
# Requirement already satisfied: setuptools in e:\games\anaconda\envs\big_data\lib\site-packages (from pycountry>=19->gtfs-kit) (65.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests>=2->gtfs-kit) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests>=2->gtfs-kit) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests>=2->gtfs-kit) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests>=2->gtfs-kit) (3.4)
# Requirement already satisfied: six>=1.7 in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (1.16.0)
# Requirement already satisfied: munch in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (2.5.0)
# Requirement already satisfied: attrs>=17 in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (22.1.0)
# Requirement already satisfied: click-plugins>=1.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (1.1.1)
# Requirement already satisfied: click>=4.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from fiona>=1.8->geopandas>=0->gtfs-kit) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from jinja2>=2.9->folium>=0->gtfs-kit) (2.1.1)
# Requirement already satisfied: colorama in e:\games\anaconda\envs\big_data\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas>=0->gtfs-kit) (0.4.6)
# Requirement already satisfied: gtfs_functions in e:\games\anaconda\envs\big_data\lib\site-packages (1.0.1)
# Requirement already satisfied: datashader in e:\games\anaconda\envs\big_data\lib\site-packages (0.14.3)
# Requirement already satisfied: numba>=0.51 in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (0.56.4)
# Requirement already satisfied: requests in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (2.28.1)
# Requirement already satisfied: pyct in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (0.4.8)
# Requirement already satisfied: pandas in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (1.5.2)
# Requirement already satisfied: colorcet in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (3.0.1)
# Requirement already satisfied: param in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (1.12.3)
# Requirement already satisfied: toolz in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (2022.12.0)
# Requirement already satisfied: numpy in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (1.23.5)
# Requirement already satisfied: dask in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (2022.12.0)
# Requirement already satisfied: scipy in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (1.9.3)
# Requirement already satisfied: pillow in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (9.2.0)
# Requirement already satisfied: datashape in e:\games\anaconda\envs\big_data\lib\site-packages (from datashader) (0.5.2)
# Requirement already satisfied: setuptools in e:\games\anaconda\envs\big_data\lib\site-packages (from numba>=0.51->datashader) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in e:\games\anaconda\envs\big_data\lib\site-packages (from numba>=0.51->datashader) (0.39.1)
# Requirement already satisfied: importlib-metadata in e:\games\anaconda\envs\big_data\lib\site-packages (from numba>=0.51->datashader) (5.1.0)
# Requirement already satisfied: partd>=0.3.10 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (1.3.0)
# Requirement already satisfied: click>=7.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (8.1.3)
# Requirement already satisfied: pyyaml>=5.3.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (6.0)
# Requirement already satisfied: packaging>=20.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (22.0)
# Requirement already satisfied: fsspec>=0.6.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (2022.11.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from dask->datashader) (2.2.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in e:\games\anaconda\envs\big_data\lib\site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: python-dateutil in e:\games\anaconda\envs\big_data\lib\site-packages (from datashape->datashader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas->datashader) (2022.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests->datashader) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests->datashader) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests->datashader) (1.26.13)
# Requirement already satisfied: colorama in e:\games\anaconda\envs\big_data\lib\site-packages (from click>=7.0->dask->datashader) (0.4.6)
# Requirement already satisfied: six in e:\games\anaconda\envs\big_data\lib\site-packages (from multipledispatch>=0.4.7->datashape->datashader) (1.16.0)
# Requirement already satisfied: locket in e:\games\anaconda\envs\big_data\lib\site-packages (from partd>=0.3.10->dask->datashader) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from importlib-metadata->numba>=0.51->datashader) (3.11.0)
# Requirement already satisfied: geopy in e:\games\anaconda\envs\big_data\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in e:\games\anaconda\envs\big_data\lib\site-packages (from geopy) (2.0)

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in e:\games\anaconda\envs\big_data\lib\site-packages (3.5.0)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (3.6.2)
# Requirement already satisfied: htmlmin==0.1.12 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: requests<2.29,>=2.24.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (2.28.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (1.10.2)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (0.13.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (2.13.3)
# Requirement already satisfied: multimethod<1.10,>=1.4 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (1.9)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (1.23.5)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (0.12.1)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (1.9.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (0.7.5)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (1.5.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (4.64.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in e:\games\anaconda\envs\big_data\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in e:\games\anaconda\envs\big_data\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (2.8.8)
# Requirement already satisfied: attrs>=19.3.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (22.1.0)
# Requirement already satisfied: Pillow in e:\games\anaconda\envs\big_data\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (9.2.0)
# Requirement already satisfied: imagehash in e:\games\anaconda\envs\big_data\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (4.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas-profiling) (2022.6)
# Requirement already satisfied: joblib>=0.14.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from phik<0.13,>=0.11.1->pandas-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in e:\games\anaconda\envs\big_data\lib\site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in e:\games\anaconda\envs\big_data\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2022.9.24)
# Requirement already satisfied: patsy>=0.5.2 in e:\games\anaconda\envs\big_data\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (0.5.3)
# Requirement already satisfied: colorama in e:\games\anaconda\envs\big_data\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six in e:\games\anaconda\envs\big_data\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in e:\games\anaconda\envs\big_data\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling) (1.4.1)

# %% [markdown]
# At first step we imported the libraries

# %%
#Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import geopy.distance
import geopandas
import gtfs_functions as gtfs
import pandas as pd
#DATASHADER
import datashader as ds
from datashader import transfer_functions as tr_fns
#from datashader.bokeh_ext import InteractiveImage
from functools import partial
#from datashader.bokeh_ext import InteractiveImage
import colorcet as cc
import datashader.transfer_functions as tf

import pandas_profiling

# %% [markdown]
# Than we unpacked the zip file with the gtfs library to DataFrames

# %%
#unpacking the zip file with the gtfs library to DataFrames
routes, stops, stop_times, trips, shapes = gtfs.import_gtfs("../gtfs.zip")

# %% [markdown]
# Google has a reference file that contains all the information about GTFS files: https://developers.google.com/transit/gtfs/reference
# - Routes - This contains information about the whole routes (it's ID, short name that is displayed on the vehicles, and description which in this case contains the first and last stop of the route)
# - Stops - Contains information about the stops in the route (It's ID, Name, and location with coordinates (With GPS coordinates that will be useful later))
# - Stop_times - Is one of the most useful DataFrames. Information about the stops and the times of arrival and departure (Which can later be used to filter out needed ones)
# - Trips - Almost the same as the routes DF but it contains the GPS coordinates of the whole Line (Which will later be useful for finding the lines with 1 transfer)
# - Shapes - Shapes contain the Coordinates of all the routes

# %% [markdown]
# Saving the Dataframes to parquet files

# %%
routes.to_parquet("routes.parquet", index=False)
stops.to_parquet("stops.parquet", index=False)
geopandas.GeoDataFrame(stop_times).to_parquet("stop_times.parquet", index=False,)
geopandas.GeoDataFrame(trips).to_parquet("trips.parquet", index=False)
geopandas.GeoDataFrame(shapes).to_parquet("shapes.parquet", index=False)

# %% [markdown]
# and reading the parquet files

# %%
routes=pd.read_parquet("routes.parquet")
stops=geopandas.read_parquet("stops.parquet")
trips=pd.read_parquet("trips.parquet")
stop_times=geopandas.read_parquet("stop_times.parquet")
shapes=geopandas.read_parquet("shapes.parquet")

# %% [markdown]
# ## Displaying the Dataframes

# %%
display("Routes: ",routes,"Stops: ", stops,
        "Stop Times: ", stop_times, 
        "Trips: ", trips,"Shapes: ", shapes)
# Out:
# 'Routes: '
#     agency_id route_id route_short_name route_long_name  route_type  \
# 0         BKK     0050                5            None           3
# 1         BKK     0070                7            None           3
# 2         BKK     0075               7E            None           3
# 3         BKK     0078               7G            None           3
# 4         BKK     0085               8E            None           3
# ..        ...      ...              ...             ...         ...
# 345       HEV       H9               H9            None         109
# 346       BKK     MP53               M3            None           3
# 347       BKK    MP531              M3A            None           3
# 348       BKK    MP533               M3            None           3
# 349       BKK    MP536              M30            None           3
#
#                                             route_desc route_color  \
# 0             Pasaréti tér / Rákospalota, Kossuth utca      009EE3
# 1    Albertfalva vasútállomás / Újpalota, Nyírpalot...      009EE3
# 2          Blaha Lujza tér M / Újpalota, Nyírpalota út      009EE3
# 3    Cinkotai autóbuszgarázs / Újpalota, Nyírpalota út      009EE3
# 4    Kelenföld vasútállomás M / Újpalota, Nyírpalot...      009EE3
# ..                                                 ...         ...
# 345                            Örs vezér tere / Csömör      ED6E86
# 346          Göncz Árpád városközpont M / Kálvin tér M      009EE3
# 347  Göncz Árpád városközpont M / Nyugati pályaudvar M      009EE3
# 348     Göncz Árpád városközpont M / Kőbánya-Kispest M      009EE3
# 349                       Nagyvárad tér M / Népliget M      4CA22F
#
#     route_text_color route_sort_order
# 0             FFFFFF               23
# 1             FFFFFF               25
# 2             FFFFFF               26
# 3             FFFFFF               27
# 4             FFFFFF               28
# ..               ...              ...
# 345           FFFFFF                9
# 346           FFFFFF              322
# 347           FFFFFF              323
# 348           FFFFFF              321
# 349           FFFFFF              324
#
# [350 rows x 9 columns]
# 'Stops: '
#      stop_id           stop_name stop_code  location_type location_sub_type  \
# 0     003209       Batthyány tér     09001            NaN              None
# 1     004903      Örs vezér tere     19795            NaN              None
# 2     007736             Gödöllő     19870            NaN              None
# 3     007817          Márta utca      None            NaN              None
# 4     007877             Bíróság      None            NaN              None
# ...      ...                 ...       ...            ...               ...
# 5383  F04834           Tetra Pak      None            NaN              None
# 5384  F04835  Budaörsi lakótelep      None            NaN              None
# 5385  F04836  Budaörsi lakótelep      None            NaN              None
# 5386  F04837          Lejtő utca      None            NaN              None
# 5387  F04838          Lejtő utca      None            NaN              None
#
#      parent_station  wheelchair_boarding stop_direction  \
# 0             09001                  NaN           None
# 1             19795                  NaN           None
# 2             19870                  NaN           None
# 3              None                  2.0            160
# 4              None                  1.0            -78
# ...             ...                  ...            ...
# 5383           None                  2.0            -49
# 5384           None                  1.0             56
# 5385           None                  1.0             72
# 5386           None                  1.0            -81
# 5387           None                  1.0             86
#
#                        geometry
# 0     POINT (19.03932 47.50678)
# 1     POINT (19.13719 47.50359)
# 2     POINT (19.35779 47.59334)
# 3     POINT (18.92950 47.42918)
# 4     POINT (18.97806 47.51954)
# ...                         ...
# 5383  POINT (18.90352 47.45783)
# 5384  POINT (18.94090 47.45569)
# 5385  POINT (18.94063 47.45564)
# 5386  POINT (18.93061 47.45961)
# 5387  POINT (18.93158 47.45942)
#
# [5388 rows x 9 columns]
# 'Stop Times: '
#          trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 0       C0418310  F04181       28980.0         28980.0              0
# 1       C0418310  F04526       29160.0         29160.0              1
# 2       C0418311  F04526       30600.0         30600.0              0
# 3       C0418311  F04181       30780.0         30780.0              1
# 4       C0418312  F04181       30780.0         30780.0              0
# ...          ...     ...           ...             ...            ...
# 810892  H8000_22  F04692       89280.0         89280.0             13
# 810893  H8000_22  F04793       89400.0         89400.0             14
# 810894  H8000_22  F04690       89520.0         89580.0             15
# 810895  H8000_22  F04688       89820.0         89820.0             16
# 810896  H8000_22  009273       90000.0         90000.0             17
#
#        stop_headsign  pickup_type drop_off_type  shape_dist_traveled route_id  \
# 0               None          NaN          None                  0.0     8140
# 1               None          NaN          None                160.0     8140
# 2               None          NaN          None                  0.0     8140
# 3               None          NaN          None                160.0     8140
# 4               None          NaN          None                  0.0     8140
# ...              ...          ...           ...                  ...      ...
# 810892          None          NaN          None              13673.0       H5
# 810893          None          NaN          None              14507.0       H5
# 810894          None          NaN          None              16297.0       H5
# 810895          None          NaN          None              19497.0       H5
# 810896          None          1.0          None              20706.0       H5
#
#         ... direction_id  shape_id                stop_name     stop_code  \
# 0       ...            0      Y701        Csepel-Királyerdő          None
# 1       ...            0      Y701  Soroksár, Molnár-sziget          None
# 2       ...            1      Y702  Soroksár, Molnár-sziget          None
# 3       ...            1      Y702        Csepel-Királyerdő          None
# 4       ...            0      Y701        Csepel-Királyerdő          None
# ...     ...          ...       ...                      ...           ...
# 810892  ...            0        22      Budakalász, Lenfonó  09191_F04692
# 810893  ...            0        22         Szentistvántelep  09209_F04793
# 810894  ...            0        22                    Pomáz  09134_F04690
# 810895  ...            0        22            Pannóniatelep  09217_F04688
# 810896  ...            0        22               Szentendre         09142
#
#        location_type  location_sub_type parent_station wheelchair_boarding  \
# 0                NaN               None           None                 2.0
# 1                NaN               None           None                 2.0
# 2                NaN               None           None                 2.0
# 3                NaN               None           None                 2.0
# 4                NaN               None           None                 2.0
# ...              ...                ...            ...                 ...
# 810892           NaN               None           None                 NaN
# 810893           NaN               None           None                 NaN
# 810894           NaN               None           None                 NaN
# 810895           NaN               None           None                 NaN
# 810896           NaN               None          09142                 NaN
#
#         stop_direction                   geometry
# 0                 None  POINT (19.10653 47.39789)
# 1                 None  POINT (19.10869 47.39824)
# 2                 None  POINT (19.10869 47.39824)
# 3                 None  POINT (19.10653 47.39789)
# 4                 None  POINT (19.10653 47.39789)
# ...                ...                        ...
# 810892            None  POINT (19.04691 47.62169)
# 810893            None  POINT (19.04316 47.62930)
# 810894            None  POINT (19.03203 47.64319)
# 810895            None  POINT (19.06529 47.65249)
# 810896            None  POINT (19.07561 47.66104)
#
# [810897 rows x 21 columns]
# 'Trips: '
#             trip_id route_id        service_id  direction_id shape_id
# 0          C0418310     8140  C04183AHPMAA-011             0     Y701
# 1          C0418311     8140  C04183AHPMAA-011             1     Y702
# 2          C0418312     8140  C04183AHPMAA-011             0     Y701
# 3          C0418313     8140  C04183AHPMAA-011             1     Y702
# 4          C0418314     8140  C04183AHPMAA-011             0     Y701
# ...             ...      ...               ...           ...      ...
# 42373  H550214_1312       H9             20858             0     1312
# 42374  H550716_1313       H9             20858             1     1313
# 42375   H55125_1312       H9             20858             0     1312
# 42376   H55179_1313       H9             20858             1     1313
# 42377      H8000_22       H5             20858             0       22
#
# [42378 rows x 5 columns]
# 'Shapes: '
#      shape_id                                           geometry
# 0        0285  LINESTRING (19.14833 47.51965, 19.14831 47.519...
# 1        0803  LINESTRING (19.08235 47.55962, 19.08243 47.559...
# 2        0976  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 3        0977  LINESTRING (19.02519 47.50723, 19.02518 47.507...
# 4           1  LINESTRING (19.03942 47.50667, 19.03941 47.507...
# ...       ...                                                ...
# 1295     Z545  LINESTRING (19.01851 47.46434, 19.01864 47.464...
# 1296     Z546  LINESTRING (18.92367 47.51776, 18.92387 47.517...
# 1297     Z895  LINESTRING (18.99852 47.49470, 18.99843 47.494...
# 1298     Z962  LINESTRING (19.04937 47.51389, 19.04941 47.513...
# 1299   a-1203  LINESTRING (19.03917 47.42709, 19.03914 47.427...
#
# [1300 rows x 2 columns]

# %% [markdown]
# There is a lot of Data with 810897 stops in a 24 hour period. Luckily we only need the
# routes that will get us to the BME I building at 8 o'clock in the morning. We also have the GPS coordinates of all the stops.
#
# Now the first step is to find the GPS coordinates of the I building
# which can be found on Google maps:
#
# ![I Building](images/I_building.png)
#
# Next we need to find all the stops that are in a 10 minute walk within the I building. This can differ from person to person but we used a 4km/h walking speed and calculated how many meters can you walk with that speed for 10 minutes time.
#
# The formula for calculating distance is:
# $s=v*t$
# where $s$ is the distance walked and $t$ is the time:
# - $4\frac{km}{h}=1,1\frac{m}{s}$
# - $10minutes=600seconds$
# - $1,1*600=660m$
#
# So the avarage person can walk 660m-s in 10 minutes. Since Google's distance uses birds eye view we used ~600m for the distance.

# %%
#variable with I building coordinates
I_building=(47.47282880598328, 19.060057869533754)
radius=(47.46980543001353, 19.05407442774218)

# %% [markdown]
# With the geopy library we can calculate the distance between two points so we iterated through the stops and checked whether the fell into this radius

# %%
print("stops that are in a 600m radius of Building I at BME: ")
stops_600=[]
for i,k in enumerate(stops["geometry"]):
    if geopy.distance.geodesic(I_building, (k.y,k.x)).m <600.0:
        print("\t-",stops["stop_id"][i])
        stops_600.append(stops["stop_id"][i])
# Out:
# stops that are in a 600m radius of Building I at BME:
# 	- 008280
# 	- 009179
# 	- 049597
# 	- 062607
# 	- 062608
# 	- 062620
# 	- 062621
# 	- 062622
# 	- 066451
# 	- 066452
# 	- 066453
# 	- 066454
# 	- 071262
# 	- F01986
# 	- F01988
# 	- F01989
# 	- F01990
# 	- F01991
# 	- F01992
# 	- F02153
# 	- F02155
# 	- F02222
# 	- F02224
# 	- F02225

# %% [markdown]
# We filter the stops and reindex them

# %%
#now we filter stops that are in a 600m radius and reset the index
stops_I=stops[stops["stop_id"].isin(stops_600)]
stops_I.reset_index(drop=True, inplace=True)
display(stops_I)
# Out:
#    stop_id                          stop_name stop_code  location_type  \
# 0   008280    Infopark (Pázmány Péter sétány)      None            NaN
# 1   009179            Petőfi híd, budai hídfő      None            NaN
# 2   049597                           BudaPart      None            NaN
# 3   062607    Infopark (Pázmány Péter sétány)      None            NaN
# 4   062608             Magyar tudósok körútja      None            NaN
# 5   062620     Egyetemváros - A38 hajóállomás      None            NaN
# 6   062621     Egyetemváros - A38 hajóállomás      None            NaN
# 7   062622             Magyar tudósok körútja      None            NaN
# 8   066451                           Infopark      None            NaN
# 9   066452                           Infopark      None            NaN
# 10  066453         Budafoki út / Dombóvári út      None            NaN
# 11  066454         Budafoki út / Dombóvári út      None            NaN
# 12  071262                           BudaPart      None            NaN
# 13  F01986          Budafoki út / Szerémi sor      None            NaN
# 14  F01988          Budafoki út / Szerémi sor      None            NaN
# 15  F01989          Budafoki út / Szerémi sor      None            NaN
# 16  F01990          Budafoki út / Szerémi sor      None            NaN
# 17  F01991          Budafoki út / Szerémi sor      None            NaN
# 18  F01992          Budafoki út / Szerémi sor      None            NaN
# 19  F02153  Budafoki út / Karinthy Frigyes út      None            NaN
# 20  F02155  Budafoki út / Karinthy Frigyes út      None            NaN
# 21  F02222            Petőfi híd, budai hídfő      None            NaN
# 22  F02224            Petőfi híd, budai hídfő      None            NaN
# 23  F02225            Petőfi híd, budai hídfő      None            NaN
#
#    location_sub_type parent_station  wheelchair_boarding stop_direction  \
# 0               None           None                  1.0            179
# 1               None           None                  1.0           -125
# 2               None           None                  1.0            103
# 3               None           None                  1.0            -83
# 4               None           None                  1.0             81
# 5               None           None                  1.0            167
# 6               None           None                  1.0            -13
# 7               None           None                  1.0            168
# 8               None           None                  1.0            -85
# 9               None           None                  1.0             96
# 10              None           None                  1.0            -75
# 11              None           None                  1.0            104
# 12              None           None                  1.0            -72
# 13              None           None                  1.0           -169
# 14              None           None                  1.0             58
# 15              None           None                  1.0           -118
# 16              None           None                  1.0           -125
# 17              None           None                  1.0             -1
# 18              None           None                  1.0             55
# 19              None           None                  1.0            114
# 20              None           None                  2.0             11
# 21              None           None                  1.0             55
# 22              None           None                  1.0           -128
# 23              None           None                  1.0             54
#
#                      geometry
# 0   POINT (19.06433 47.46924)
# 1   POINT (19.05892 47.47680)
# 2   POINT (19.05716 47.46844)
# 3   POINT (19.06299 47.46985)
# 4   POINT (19.06367 47.47147)
# 5   POINT (19.06354 47.47329)
# 6   POINT (19.06359 47.47373)
# 7   POINT (19.06386 47.47218)
# 8   POINT (19.05972 47.46917)
# 9   POINT (19.06050 47.46907)
# 10  POINT (19.05365 47.46981)
# 11  POINT (19.05438 47.46965)
# 12  POINT (19.05794 47.46855)
# 13  POINT (19.05262 47.47436)
# 14  POINT (19.05318 47.47362)
# 15  POINT (19.05281 47.47368)
# 16  POINT (19.05285 47.47387)
# 17  POINT (19.05257 47.47282)
# 18  POINT (19.05374 47.47409)
# 19  POINT (19.05411 47.47583)
# 20  POINT (19.05316 47.47541)
# 21  POINT (19.05927 47.47657)
# 22  POINT (19.05896 47.47667)
# 23  POINT (19.05959 47.47693)

# %% [markdown]
# We selected the routes which has stops within 600 m distance

# %%
#Next we selected the routes with has stops within a 600m radius of the I building
shapes_within_i=[]
for j,i in enumerate(shapes["geometry"]):
    for k in stops_I["geometry"]:
        if k.x in i.coords.xy[0] and k.y in i.coords.xy[1]:
            shapes_within_i.append(shapes["shape_id"][j])

# %% [markdown]
# After we filtered the shapes of the selected ones

# %%
#We filter the shapes with the selected ones
shapes_I=shapes[shapes["shape_id"].isin(shapes_within_i)]
shapes_I.reset_index(drop=True, inplace=True)
display(shapes_I)
# Out:
#    shape_id                                           geometry
# 0      0976  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 1      0977  LINESTRING (19.02519 47.50723, 19.02518 47.507...
# 2      2064  LINESTRING (19.07132 47.49604, 19.07127 47.496...
# 3      AH19  LINESTRING (19.06299 47.46985, 19.06299 47.469...
# 4      B692  LINESTRING (19.04835 47.47750, 19.04834 47.477...
# 5      B693  LINESTRING (19.02519 47.50723, 19.02518 47.507...
# 6      B824  LINESTRING (19.07134 47.49607, 19.07132 47.496...
# 7      BM08  LINESTRING (19.08126 47.50041, 19.08131 47.500...
# 8      BM09  LINESTRING (19.05793 47.46850, 19.05737 47.468...
# 9      DO19  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 10     DX77  LINESTRING (18.99254 47.47332, 18.99258 47.473...
# 11     EJ39  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 12     EJ40  LINESTRING (19.04835 47.47750, 19.04834 47.477...
# 13     IJ60  LINESTRING (19.02339 47.46447, 19.02341 47.464...
# 14     IJ62  LINESTRING (19.10815 47.50039, 19.10813 47.500...
# 15     IL26  LINESTRING (19.14204 47.54704, 19.14223 47.546...
# 16     IL59  LINESTRING (19.05310 47.46442, 19.05302 47.464...
# 17     L755  LINESTRING (19.02339 47.46447, 19.02341 47.464...
# 18     N087  LINESTRING (19.02341 47.46447, 19.02343 47.464...
# 19     N088  LINESTRING (19.02937 47.54877, 19.02937 47.548...
# 20     N092  LINESTRING (19.04336 47.46225, 19.04336 47.462...
# 21     NQ46  LINESTRING (19.10815 47.50039, 19.10813 47.500...
# 22     NU04  LINESTRING (19.06787 47.47950, 19.06801 47.479...
# 23     O350  LINESTRING (19.02937 47.54877, 19.02937 47.548...
# 24     PJ53  LINESTRING (19.11237 47.51975, 19.11207 47.519...
# 25     QH60  LINESTRING (19.03593 47.47628, 19.03596 47.476...
# 26     QZ99  LINESTRING (19.02957 47.54837, 19.02964 47.548...
# 27     RA01  LINESTRING (19.10785 47.50065, 19.10796 47.500...
# 28     RA02  LINESTRING (19.02298 47.46480, 19.02318 47.464...
# 29     RA04  LINESTRING (19.02298 47.46480, 19.02318 47.464...
# 30     RA05  LINESTRING (19.02298 47.46480, 19.02318 47.464...
# 31     RA99  LINESTRING (19.02298 47.46480, 19.02318 47.464...
# 32     RL95  LINESTRING (19.05793 47.46850, 19.05737 47.468...
# 33     RM00  LINESTRING (19.05921 47.47663, 19.05948 47.476...
# 34     RM48  LINESTRING (19.05793 47.46850, 19.05737 47.468...
# 35     RM50  LINESTRING (18.99254 47.47332, 18.99258 47.473...
# 36     SB36  LINESTRING (19.14204 47.54704, 19.14223 47.546...
# 37     SB37  LINESTRING (18.97078 47.38799, 18.97089 47.388...
# 38     SB38  LINESTRING (18.97078 47.38799, 18.97089 47.388...
# 39     SB39  LINESTRING (19.08131 47.50037, 19.08081 47.500...
# 40     TD49  LINESTRING (19.04336 47.46225, 19.04336 47.462...
# 41     TD55  LINESTRING (19.10815 47.50039, 19.10813 47.500...
# 42     TL38  LINESTRING (19.10815 47.50039, 19.10813 47.500...
# 43     TT13  LINESTRING (19.04336 47.46225, 19.04336 47.462...
# 44     VN41  LINESTRING (19.04197 47.55013, 19.04204 47.550...
# 45     VN42  LINESTRING (19.10785 47.50065, 19.10796 47.500...
# 46     XC11  LINESTRING (19.04881 47.47727, 19.04897 47.477...
# 47     XC12  LINESTRING (18.95855 47.38888, 18.95851 47.388...
# 48     XC13  LINESTRING (19.04912 47.44917, 19.04908 47.449...
# 49     XD31  LINESTRING (18.96798 47.50062, 18.96806 47.500...
# 50     XD69  LINESTRING (19.06801 47.47952, 19.06792 47.479...
# 51     XD70  LINESTRING (18.98954 47.49793, 18.98953 47.497...
# 52     XO16  LINESTRING (19.02296 47.46476, 19.02298 47.464...
# 53     XO17  LINESTRING (19.02296 47.46476, 19.02298 47.464...
# 54     XO18  LINESTRING (19.02296 47.46476, 19.02298 47.464...
# 55     XO20  LINESTRING (19.02629 47.56800, 19.02621 47.568...
# 56     XS57  LINESTRING (19.06787 47.47950, 19.06801 47.479...
# 57     XS63  LINESTRING (18.95484 47.48671, 18.95483 47.486...

# %% [markdown]
# We checked with matplotlib how the lines will look like

# %%
#Lets see how these lines look like (The datashader one will be much better)
for i in shapes_I["geometry"]:
    x,y=i.coords.xy
    plt.plot(x,y)
    plt.scatter(I_building[1], I_building[0])
plt.show()

# %% [markdown]
# We filter by the Route IDs and drop the duplicates

# %%
#Now we filter in the Trips DataFrame because it has Route IDs and we drop the duplicates
trips_I=trips[trips["shape_id"].isin(shapes_I["shape_id"])]
trips_I.drop_duplicates(subset=["route_id"])
# Out:
#             trip_id route_id          service_id  direction_id shape_id
# 1446   C34268105116     3060   C34268REHHKMK-011             1     B692
# 1484   C34268120869     3040   C34268REHHKMK-011             0     0977
# 7436      C50522131     1530    C50522AHCKVA-011             1     DX77
# 7440     C505221645     1540    C50522AHCKVA-011             1     RM50
# 16250    C530791140     9180    C53079AHPMAA-021             1     VN42
# 18201   C537446103J     3410    C53744AHCPJ-0051             1     TL38
# 20469    C540151008     1335   C54015TOHCMAA-011             0     SB39
# 24651      C5450110     1070    C54501AHCWA-0011             0     BM09
# 31736    C547346553     2120    C54734AHCCsZ-031             1     QH60
# 31743    C547346581     2121    C54734AHCCsZ-031             0     XD69
# 31751    C547346611     2122    C54734AHCCsZ-031             0     XS57
# 31958     C54746106     0330    C54746AHCMAA-031             0     XC11
# 32099       C547871     3010  C54787RAAHHMAA-021             0     N087
# 34332  C5494311793J     3170  C54943RAAHHSZL-031             0     NQ46
# 39977     C55600102     9010    C55600AHPSZB-011             0     RA04

# %% [markdown]
# We filter the routes by route ID to get the routes, has stops within 600 m walking distance

# %%
#And now we can filter the routes with the route ID so we can have the routes that has stops within a 600m radius of the I building
routes_I=routes[routes["route_id"].isin(trips_I["route_id"])]
routes_I
# Out:
#     agency_id route_id route_short_name route_long_name  route_type  \
# 28        BKK     0330               33            None           3
# 85        BKK     1070              107            None           3
# 114       BKK     1335             133E            None           3
# 135       BKK     1530              153            None           3
# 136       BKK     1540              154            None           3
# 184       BKK     2120              212            None           3
# 185       BKK     2121             212A            None           3
# 186       BKK     2122             212B            None           3
# 240       BKK     3010                1            None           0
# 246       BKK     3040                4            None           0
# 247       BKK     3060                6            None           0
# 250       BKK     3170               17            None           0
# 257       BKK     3410               41            None           0
# 296       BKK     9010              901            None           3
# 303       BKK     9180              918            None           3
#
#                                             route_desc route_color  \
# 28    Móricz Zsigmond körtér M / Nagytétény, ipartelep      009EE3
# 85                      BudaPart / Keleti pályaudvar M      009EE3
# 114  Újpalota, Nyírpalota út / Nagytétény, Erdélyi ...      009EE3
# 135   Infopark (Pázmány Péter sétány) / Gazdagréti tér      009EE3
# 136                          BudaPart / Gazdagréti tér      009EE3
# 184           Boráros tér H / Normafa, látogatóközpont      009EE3
# 185                           Boráros tér H / Svábhegy      009EE3
# 186                   Boráros tér H / Csillebérc, KFKI      009EE3
# 240  Kelenföld vasútállomás M / Bécsi út / Vörösvár...      FFD800
# 246              Széll Kálmán tér M / Újbuda-központ M      FFD800
# 247      Széll Kálmán tér M / Móricz Zsigmond körtér M      FFD800
# 250              Savoya Park / Bécsi út / Vörösvári út      FFD800
# 257        Bécsi út / Vörösvári út / Budafok kocsiszín      FFD800
# 296  Kelenföld vasútállomás M / Bécsi út / Vörösvár...      000000
# 303   Kelenföld vasútállomás M / Óbudai autóbuszgarázs      000000
#
#     route_text_color route_sort_order
# 28            FFFFFF               59
# 85            FFFFFF              158
# 114           FFFFFF              188
# 135           FFFFFF              209
# 136           FFFFFF              210
# 184           FFFFFF              258
# 185           FFFFFF              259
# 186           FFFFFF              260
# 240           000000               14
# 246           000000               22
# 247           000000               24
# 250           000000               39
# 257           000000               72
# 296           FFFFFF              326
# 303           FFFFFF              335

# %% [markdown]
# We filtered the stops between 7:15 and 7:50, so we still have 10 minutes to walk to the building. In the dataframe the stop times was in seconds, so we need to convert these to know the time

# %%
# Now we need filter the stops that are between 7:15 and 7:50 
# (so we still have the 10 minutes to walk to the building)
#The DataFrame stop_times has the times in second so we converted these
stop_7=stop_times[stop_times["arrival_time"]<28200]
stop_7=stop_7[stop_7["arrival_time"]>26100]
stop_7.reset_index(drop=True, inplace=True)

# %% [markdown]
# So we have the times and we filter the stops that are in radius

# %%
#we have the times and we filter the stops that are in the radius
stop_7_8=stop_7[stop_7["stop_id"].isin(stops_I["stop_id"])]
stop_7_8
# Out:
#             trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 654    C34268106997  F02153       26520.0         26520.0              1
# 655    C34268106997  F02225       26580.0         26580.0              2
# 672     C3426814107  F02153       27480.0         27480.0              1
# 673     C3426814107  F02225       27540.0         27540.0              2
# 766      C342682005  F01992       26160.0         26160.0              1
# ...             ...     ...           ...             ...            ...
# 25147   C5478720734  066452       27840.0         27840.0              7
# 25186   C5478732343  066451       26220.0         26220.0             24
# 25187   C5478732343  066453       26280.0         26280.0             25
# 25200   C5478732344  066454       27960.0         27960.0              6
# 25201   C5478732344  066452       28020.0         28020.0              7
#
#                   stop_headsign  pickup_type drop_off_type  \
# 654          Széll Kálmán tér M          NaN          None
# 655          Széll Kálmán tér M          NaN          None
# 672          Széll Kálmán tér M          NaN          None
# 673          Széll Kálmán tér M          NaN          None
# 766          Széll Kálmán tér M          NaN          None
# ...                         ...          ...           ...
# 25147   Bécsi út / Vörösvári út          NaN          None
# 25186  Kelenföld vasútállomás M          NaN          None
# 25187  Kelenföld vasútállomás M          NaN          None
# 25200   Bécsi út / Vörösvári út          NaN          None
# 25201   Bécsi út / Vörösvári út          NaN          None
#
#        shape_dist_traveled route_id  ... direction_id  shape_id  \
# 654                  477.0     3060  ...            1      B692
# 655                  960.0     3060  ...            1      B692
# 672                  477.0     3060  ...            1      B692
# 673                  960.0     3060  ...            1      B692
# 766                  546.0     3040  ...            1      0976
# ...                    ...      ...  ...          ...       ...
# 25147               3653.0     3010  ...            0      N087
# 25186              14504.0     3010  ...            1      N088
# 25187              14970.0     3010  ...            1      N088
# 25200               3181.0     3010  ...            0      N087
# 25201               3653.0     3010  ...            0      N087
#
#                                stop_name stop_code location_type  \
# 654    Budafoki út / Karinthy Frigyes út      None           NaN
# 655              Petőfi híd, budai hídfő      None           NaN
# 672    Budafoki út / Karinthy Frigyes út      None           NaN
# 673              Petőfi híd, budai hídfő      None           NaN
# 766            Budafoki út / Szerémi sor      None           NaN
# ...                                  ...       ...           ...
# 25147                           Infopark      None           NaN
# 25186                           Infopark      None           NaN
# 25187         Budafoki út / Dombóvári út      None           NaN
# 25200         Budafoki út / Dombóvári út      None           NaN
# 25201                           Infopark      None           NaN
#
#        location_sub_type parent_station wheelchair_boarding  stop_direction  \
# 654                 None           None                 1.0             114
# 655                 None           None                 1.0              54
# 672                 None           None                 1.0             114
# 673                 None           None                 1.0              54
# 766                 None           None                 1.0              55
# ...                  ...            ...                 ...             ...
# 25147               None           None                 1.0              96
# 25186               None           None                 1.0             -85
# 25187               None           None                 1.0             -75
# 25200               None           None                 1.0             104
# 25201               None           None                 1.0              96
#
#                         geometry
# 654    POINT (19.05411 47.47583)
# 655    POINT (19.05959 47.47693)
# 672    POINT (19.05411 47.47583)
# 673    POINT (19.05959 47.47693)
# 766    POINT (19.05374 47.47409)
# ...                          ...
# 25147  POINT (19.06050 47.46907)
# 25186  POINT (19.05972 47.46917)
# 25187  POINT (19.05365 47.46981)
# 25200  POINT (19.05438 47.46965)
# 25201  POINT (19.06050 47.46907)
#
# [181 rows x 21 columns]

# %% [markdown]
# We created a small dictionary to be able to see the stops short names (the real number of the vechiles), and added them to the dataframe

# %%
#we created a small dictionary to be able to see the stops short names 
# (the ones that we see on the vehicles) and added them to the df
values_dict={"3060":"6", "3040":"4", "1530":"153", "1540":"154", "1335":"133E", '1070':'107', '2120':'212', '2121':"212A",
       '2122':"212B", '0330':"33", '3010':"1"}
short_names=[]
for i in stop_7_8["route_id"]:
    for k in values_dict:
        if i==k:
            short_names.append(values_dict[k])
stop_7_8["short_names"]=short_names
stop_7_8
# Out:
#             trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 654    C34268106997  F02153       26520.0         26520.0              1
# 655    C34268106997  F02225       26580.0         26580.0              2
# 672     C3426814107  F02153       27480.0         27480.0              1
# 673     C3426814107  F02225       27540.0         27540.0              2
# 766      C342682005  F01992       26160.0         26160.0              1
# ...             ...     ...           ...             ...            ...
# 25147   C5478720734  066452       27840.0         27840.0              7
# 25186   C5478732343  066451       26220.0         26220.0             24
# 25187   C5478732343  066453       26280.0         26280.0             25
# 25200   C5478732344  066454       27960.0         27960.0              6
# 25201   C5478732344  066452       28020.0         28020.0              7
#
#                   stop_headsign  pickup_type drop_off_type  \
# 654          Széll Kálmán tér M          NaN          None
# 655          Széll Kálmán tér M          NaN          None
# 672          Széll Kálmán tér M          NaN          None
# 673          Széll Kálmán tér M          NaN          None
# 766          Széll Kálmán tér M          NaN          None
# ...                         ...          ...           ...
# 25147   Bécsi út / Vörösvári út          NaN          None
# 25186  Kelenföld vasútállomás M          NaN          None
# 25187  Kelenföld vasútállomás M          NaN          None
# 25200   Bécsi út / Vörösvári út          NaN          None
# 25201   Bécsi út / Vörösvári út          NaN          None
#
#        shape_dist_traveled route_id  ... shape_id  \
# 654                  477.0     3060  ...     B692
# 655                  960.0     3060  ...     B692
# 672                  477.0     3060  ...     B692
# 673                  960.0     3060  ...     B692
# 766                  546.0     3040  ...     0976
# ...                    ...      ...  ...      ...
# 25147               3653.0     3010  ...     N087
# 25186              14504.0     3010  ...     N088
# 25187              14970.0     3010  ...     N088
# 25200               3181.0     3010  ...     N087
# 25201               3653.0     3010  ...     N087
#
#                                stop_name stop_code location_type  \
# 654    Budafoki út / Karinthy Frigyes út      None           NaN
# 655              Petőfi híd, budai hídfő      None           NaN
# 672    Budafoki út / Karinthy Frigyes út      None           NaN
# 673              Petőfi híd, budai hídfő      None           NaN
# 766            Budafoki út / Szerémi sor      None           NaN
# ...                                  ...       ...           ...
# 25147                           Infopark      None           NaN
# 25186                           Infopark      None           NaN
# 25187         Budafoki út / Dombóvári út      None           NaN
# 25200         Budafoki út / Dombóvári út      None           NaN
# 25201                           Infopark      None           NaN
#
#       location_sub_type  parent_station wheelchair_boarding stop_direction  \
# 654                None            None                 1.0            114
# 655                None            None                 1.0             54
# 672                None            None                 1.0            114
# 673                None            None                 1.0             54
# 766                None            None                 1.0             55
# ...                 ...             ...                 ...            ...
# 25147              None            None                 1.0             96
# 25186              None            None                 1.0            -85
# 25187              None            None                 1.0            -75
# 25200              None            None                 1.0            104
# 25201              None            None                 1.0             96
#
#                         geometry short_names
# 654    POINT (19.05411 47.47583)           6
# 655    POINT (19.05959 47.47693)           6
# 672    POINT (19.05411 47.47583)           6
# 673    POINT (19.05959 47.47693)           6
# 766    POINT (19.05374 47.47409)           4
# ...                          ...         ...
# 25147  POINT (19.06050 47.46907)           1
# 25186  POINT (19.05972 47.46917)           1
# 25187  POINT (19.05365 47.46981)           1
# 25200  POINT (19.05438 47.46965)           1
# 25201  POINT (19.06050 47.46907)           1
#
# [181 rows x 22 columns]

# %% [markdown]
# To see the whole pathways we filtered it with the trip_ID.

# %%
#We have the stops but we need the whole Pathways so we filter those with the trip_id
#since it contains the whole routes
pathways_7_8=stop_times[stop_times["trip_id"].isin(stop_7_8["trip_id"])]

# %% [markdown]
# After we add the short names to it.

# %%
#And we also add the short names to it
short_names=[]
for i in pathways_7_8["route_id"]:
    for k in values_dict:
        if i==k:
            short_names.append(values_dict[k])
pathways_7_8["short_names"]=short_names
pathways_7_8.reset_index(drop=True, inplace=True)
pathways_7_8.head()
# Out:
#         trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 0  C34268106997  009220       26400.0         26400.0              0
# 1  C34268106997  F02153       26520.0         26520.0              1
# 2  C34268106997  F02225       26580.0         26580.0              2
# 3  C34268106997  F01374       26700.0         26700.0              3
# 4  C34268106997  F01380       26820.0         26820.0              4
#
#         stop_headsign  pickup_type drop_off_type  shape_dist_traveled  \
# 0  Széll Kálmán tér M          NaN             1                  0.0
# 1  Széll Kálmán tér M          NaN          None                477.0
# 2  Széll Kálmán tér M          NaN          None                960.0
# 3  Széll Kálmán tér M          NaN          None               1622.0
# 4  Széll Kálmán tér M          NaN          None               1942.0
#
#   route_id  ... shape_id                          stop_name stop_code  \
# 0     3060  ...     B692           Móricz Zsigmond körtér M      None
# 1     3060  ...     B692  Budafoki út / Karinthy Frigyes út      None
# 2     3060  ...     B692            Petőfi híd, budai hídfő      None
# 3     3060  ...     B692                      Boráros tér H      None
# 4     3060  ...     B692         Mester utca / Ferenc körút      None
#
#   location_type location_sub_type  parent_station wheelchair_boarding  \
# 0           NaN              None            None                 1.0
# 1           NaN              None            None                 1.0
# 2           NaN              None            None                 1.0
# 3           NaN              None            None                 2.0
# 4           NaN              None            None                 1.0
#
#   stop_direction                   geometry short_names
# 0           None  POINT (19.04835 47.47750)           6
# 1            114  POINT (19.05411 47.47583)           6
# 2             54  POINT (19.05959 47.47693)           6
# 3             54  POINT (19.06670 47.48038)           6
# 4             14  POINT (19.06885 47.48275)           6
#
# [5 rows x 22 columns]

# %%
pathways_7_8_without_geo=pathways_7_8.iloc[:,:-2]
pathways_7_8_without_geo["short_names"]=short_names

# %%
profile = pathways_7_8_without_geo.profile_report(title="Pathways without transfer")
profile.to_file(output_file="pathways_without transfer.html")
# Out:
# Summarize dataset: 100%|██████████| 72/72 [00:22<00:00,  3.26it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:07<00:00,  7.20s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.64s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.70it/s]

# %% [markdown]
# # Pandas profiling

# %% [markdown]
# You can open the pandas profiling HTML file it will be in the final solution directory
#
# The main things that we conclude from the report is the frequency of the stop names:
# Where we can see the most frequent ones.
#
# ![stop names](final_solution\images\stops_names.png)
#
# We can see that these stops are part of the 4-6 tram route and 1 tram route.
#
# If we take a look at the short names of the vehicles we can see the frequency of the routes:
#
# ![stop names](final_solution\images\short_names.png)
#
# Here we can see that the 1 tram is the most frequent. If we add the 4-6 tram together we get ~ the same number of routes.
# The other vehicle that's really frequent is the 133E bus which is also goes around in 5-10 minutes in the morning.

# %% [markdown]
# # DataShader visualizations

# %% [markdown]
# ## Preprocessing the data

# %% [markdown]
# At first we extracted the unique trip IDs, so this way we could calculate distances by time

# %%
#extracting the unique trip ID-s so we can calculate the time distances
my=dict(zip(pathways_7_8["trip_id"],pathways_7_8["short_names"]))
temp=[]
res={}
for i,k in my.items():
    if k not in temp:
        temp.append(k)
        res[i]=k
res
# Out:
# {'C34268106997': '6',
#  'C342682005': '4',
#  'C50522179': '153',
#  'C50522201': '154',
#  'C54015135': '133E',
#  'C5450110': '107',
#  'C547346653': '212',
#  'C547346659': '212A',
#  'C547346683': '212B',
#  'C5474657': '33',
#  'C5478717602': '1'}

# %%
#unique Trip ID-s
list(res.keys())
# Out:
# ['C34268106997',
#  'C342682005',
#  'C50522179',
#  'C50522201',
#  'C54015135',
#  'C5450110',
#  'C547346653',
#  'C547346659',
#  'C547346683',
#  'C5474657',
#  'C5478717602']

# %%
#Pathways with only one trip ID
pathways_one=pathways_7_8[pathways_7_8["trip_id"].isin(res.keys())]

# %%
#creating an array with unique values to use in a for loop
for_loop=pathways_7_8["short_names"].unique()
for_loop
# Out:
# array(['6', '4', '153', '154', '133E', '107', '212', '212A', '212B', '33',
#        '1'], dtype=object)

# %%
# appending the time distances to a list
time_from_origin=[]
stoppyka=stops_I.drop_duplicates(subset="stop_name")["stop_name"]
for i in for_loop:
    route=pathways_one[pathways_one["short_names"]==i]
    dep_time=list(route[route["stop_name"].isin(stoppyka)]["departure_time"])[0]
    time_from_origin.append(route["departure_time"].apply(lambda x: abs(x-dep_time)))

# %%
#and extracting the times from the time_from origin list so we can append it to the pathways_one
times=[]
for i in time_from_origin:
    for k in i:
        times.append(k)

# %%
pathways_one["time_distance"]=times

# %%
#creating a function to make seconds to hours and minutes
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60
     
    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %%
#using that function to calculate the time it takes to get to the I building
pathways_one["time_to_school"]=pathways_one["time_distance"].apply(lambda x: convert(x)+" + 10 minute walk")
#and creating a different scale for the time distances so we can create a heatmap with it
pathways_one["time_distance"]=pathways_one["time_distance"].apply(lambda x: 0 if x==0 else  -1*x)

# %%
#making a df just for the data we need
geometry_x=[]
geometry_y=[]
for i in pathways_one["geometry"]:
    geometry_x.append(i.x)
    geometry_y.append(i.y)
geometry_x_tuple=tuple(geometry_x)
geometry_y_tuple=tuple(geometry_y)
geometry_df=pd.DataFrame({
    'x_coor':geometry_x_tuple,
    'y_coor':geometry_y_tuple,
    'stop_name':pathways_one['stop_name'],
    "z":pathways_one["time_distance"]
})
mmt=[]

map_values1 = geometry_df[['y_coor','x_coor','z']]
data = map_values1.values.tolist()

# %%
#making a df just for the data we need
geometry_x=[]
geometry_y=[]
for i in pathways_one["geometry"]:
    geometry_x.append(i.x)
    geometry_y.append(i.y)
geometry_x_tuple=tuple(geometry_x)
geometry_y_tuple=tuple(geometry_y)
geometry_df=pd.DataFrame({
    'x_coor':geometry_x_tuple,
    'y_coor':geometry_y_tuple,
    'stop_name':pathways_one['stop_name'],
    "z":pathways_one["time_distance"]
})
mmt=[]
ido = pathways_one['departure_time']
for i in ido:
    mmt.append(convert(i))
geometry_df['get_on'] = mmt

map_values1 = geometry_df[['y_coor','x_coor','z']]
data = map_values1.values.tolist()
geometry_df["time_to_school"]=pathways_one["time_to_school"]
geometry_df["vehicle"]=pathways_one["short_names"]
geometry_df
# Out:
#          x_coor     y_coor                          stop_name       z  \
# 0     19.048349  47.477499           Móricz Zsigmond körtér M  -120.0
# 1     19.054107  47.475827  Budafoki út / Karinthy Frigyes út     0.0
# 2     19.059586  47.476933            Petőfi híd, budai hídfő   -60.0
# 3     19.066698  47.480376                      Boráros tér H  -180.0
# 4     19.068848  47.482751         Mester utca / Ferenc körút  -300.0
# ...         ...        ...                                ...     ...
# 1646  19.058868  47.536294          Népfürdő utca / Árpád híd -2160.0
# 1647  19.045207  47.539593                   Szentlélek tér H -2280.0
# 1648  19.039960  47.541517                        Flórián tér -2400.0
# 1649  19.033456  47.545957              Óbudai rendelőintézet -2460.0
# 1650  19.029370  47.548766            Bécsi út / Vörösvári út -2580.0
#
#        get_on            time_to_school vehicle
# 0     7:20:00  0:02:00 + 10 minute walk       6
# 1     7:22:00  0:00:00 + 10 minute walk       6
# 2     7:23:00  0:01:00 + 10 minute walk       6
# 3     7:25:00  0:03:00 + 10 minute walk       6
# 4     7:27:00  0:05:00 + 10 minute walk       6
# ...       ...                       ...     ...
# 1646  7:51:00  0:36:00 + 10 minute walk       1
# 1647  7:53:00  0:38:00 + 10 minute walk       1
# 1648  7:55:00  0:40:00 + 10 minute walk       1
# 1649  7:56:00  0:41:00 + 10 minute walk       1
# 1650  7:58:00  0:43:00 + 10 minute walk       1
#
# [300 rows x 7 columns]

# %%
geometry_df.reset_index(inplace=True)

# %% [markdown]
# ## Visualizing the extracted Data

# %% [markdown]
# Here we used datashader as the canvas and plotly to make the plot interactive

# %%
#import pandas as pd
#!pip install plotly
import plotly.express as px
dff = geometry_df.query('y_coor < 47.548766').query('y_coor > 47.387982').query('x_coor > 18.954419').query('x_coor < 19.142015')
#bme_i = 47.47277215114886, 19.060034103922074
import plotly
#datashader steps
cvs = ds.Canvas(plot_width=1000, plot_height=1000)
agg = cvs.points(dff, x='x_coor', y='y_coor')
# agg is an xarray object, see http://xarray.pydata.org/en/stable/ for more details
coords_lat, coords_lon = agg.coords['y_coor'].values, agg.coords['x_coor'].values
# Corners of the image, which need to be passed to mapbox
coordinates = [[coords_lon[0], coords_lat[0]],
               [coords_lon[-1], coords_lat[0]],
               [coords_lon[-1], coords_lat[-1]],
               [coords_lon[0], coords_lat[-1]]]

from colorcet import fire
import plotly.graph_objects as go
import datashader.transfer_functions as tf
img = tf.shade(agg, )[::-1].to_pil()

import plotly.express as px
# Trick to create rapidly a figure with mapbox axes
#fig = px.density_mapbox(geometry_df, lat=geometry_df.y_coor, lon= geometry_df.x_coor,zoom=12, hover_name='stop_name', 
#                        hover_data=["x_coor", "y_coor"], radius=5, labels={'get_on':'get_on', 'time_to_school':'time_to_school'})
fig = px.density_mapbox(geometry_df, lat = geometry_df.y_coor, lon = geometry_df.x_coor, z=geometry_df.z,
                        radius=30,
                        hover_name="stop_name",
                        hover_data=["x_coor","y_coor","time_to_school","vehicle"],
                        center = dict(lat = 47.47277215114886, lon = 19.060034103922074),
                        zoom = 12,
                        mapbox_style = 'open-street-map',
                        #color_continuous_scale = 'viridis',
                        color_continuous_scale= [
                                        (0.0, "green"),
                                        (0.2, "yellow"),
                            
                                        (0.5,"red"),
                                        (1, "red"),
                                        ]
                        )


#point to BME
fig.add_trace(go.Scattermapbox(
        lat=[47.47277215114886],
        lon=[19.060034103922074],
        marker=go.scattermapbox.Marker(
            size=10,
            color='rgb(0, 144, 144)',
            opacity=0.7
        ),
        text=["BME I Epulet"],
    ) )
# Add the datashader image as a mapbox layer image

fig.update_layout(mapbox_style="carto-darkmatter",
                 coloraxis={"colorscale":[
                                        (0.0, "green"),
                                        (0.2, "yellow"),
                                        (0.5,"red"),
                                        (1, "red"),
                                        ],
                            "reversescale":True,
                            "colorbar_tickmode":"array",
                            "colorbar_tickvals":geometry_df["z"][[0,7,12,103,241,299]],
                            "colorbar_ticktext":geometry_df["time_to_school"][[0,7,12,103,241,299]],
                            }
                            ,
                            
                 mapbox_layers = [
                {
                    "sourcetype": "image",
                    "source": img,
                    "coordinates": coordinates,
                }])


fig.show()

# %% [markdown]
# Now We see a heatmap with stops in the function of time distance from the I building.
# Lets visualize the distribution of these stops with Datashader

# %%
#making a df just for the data we need
geometry_x=[]
geometry_y=[]
for i in pathways_7_8["geometry"]:
    geometry_x.append(i.x)
    geometry_y.append(i.y)
geometry_x_tuple=tuple(geometry_x)
geometry_y_tuple=tuple(geometry_y)
geometry_df=pd.DataFrame({
    'x_coor':geometry_x_tuple,
    'y_coor':geometry_y_tuple,
    'stop_name':pathways_7_8['stop_name']
})
mmt=[]
ido = pathways_7_8['departure_time']
for i in ido:
    mmt.append(convert(i))
geometry_df['get_on'] = mmt

#7:50 is 28200 in seconds
t_to_school=[]
for t in ido:
    t_to_school.append(int((28200-t)/60))
geometry_df['time_to_school']=t_to_school

# %%
#import pandas as pd
#!pip install plotly
import plotly.express as px
geometry_df=geometry_df.query('time_to_school>=0')
dff = geometry_df.query('y_coor < 47.548766').query('y_coor > 47.387982').query('x_coor > 18.954419').query('x_coor < 19.142015').query('time_to_school>10')
#bme_i = 47.47277215114886, 19.060034103922074
import plotly
#datashader steps
cvs = ds.Canvas(plot_width=1000, plot_height=1000)
agg = cvs.points(dff, x='x_coor', y='y_coor')
# agg is an xarray object, see http://xarray.pydata.org/en/stable/ for more details
coords_lat, coords_lon = agg.coords['y_coor'].values, agg.coords['x_coor'].values
# Corners of the image, which need to be passed to mapbox
coordinates = [[coords_lon[0], coords_lat[0]],
               [coords_lon[-1], coords_lat[0]],
               [coords_lon[-1], coords_lat[-1]],
               [coords_lon[0], coords_lat[-1]]]

from colorcet import fire
import plotly.graph_objects as go
import datashader.transfer_functions as tf
img = tf.shade(agg, cmap=fire)[::-1].to_pil()

import plotly.express as px
# Trick to create rapidly a figure with mapbox axes
fig = px.density_mapbox(geometry_df, lat=geometry_df.y_coor, lon= geometry_df.x_coor,zoom=12, hover_name='stop_name', 
                        hover_data=["x_coor", "y_coor",'time_to_school','get_on'], radius=5 )
#labels={'get_on':'get_on', 'time_to_school':'time_to_school'}
'''
fig = go.Densitymapbox(geometry_df, lat=geometry_df.y_coor, long= geometry_df.x_coor, hover_name='stop_name', 
                        hover_data=["x_coor", "y_coor"], labels={'get_on':'get on', 'time_to_school':'time to school'})
'''
#point to BME
fig.add_trace(go.Scattermapbox(
        lat=[47.47277215114886],
        lon=[19.060034103922074],
        marker=go.scattermapbox.Marker(
            size=10,
            color='rgb(0, 144, 144)',
            opacity=0.7
        ),
        text=["BME I Epulet"],
    ) )
# Add the datashader image as a mapbox layer image
fig.update_layout(mapbox_style="carto-darkmatter",
                 mapbox_layers = [
                {
                    "sourcetype": "image",
                    "source": img,
                    "coordinates": coordinates
                }]
)
fig.show()

# %% [markdown]
# Here we can seee the same thing we saw with the pandas profiling. The 4-6 route and the 1 tram route are the most bright because they are the most frequent routes.

# %% [markdown]
# Lets Visualize the routes

# %%
import shapely
lats = []
lons = []
names = []

for feature, name in zip(shapes_I.geometry, shapes_I["shape_id"]):
    if isinstance(feature, shapely.geometry.linestring.LineString):
        linestrings = [feature]
    elif isinstance(feature, shapely.geometry.multilinestring.MultiLineString):
        linestrings = feature.geoms
    else:
        continue
    for linestring in linestrings:
        x, y = linestring.xy
        lats = np.append(lats, y)
        lons = np.append(lons, x)
        names = np.append(names, [name]*len(y))
        lats = np.append(lats, None)
        lons = np.append(lons, None)
        names = np.append(names, None)

fig = px.line_mapbox(lat=lats, lon=lons, hover_name=names)

fig.add_trace(go.Scattermapbox(
        lat=[47.47277215114886],
        lon=[19.060034103922074],
        marker=go.scattermapbox.Marker(
            size=10,
            color='rgb(0, 144, 144)',
            opacity=0.7
        ),
        text=["BME I Epulet"],))

fig.update_layout(mapbox_style="carto-darkmatter",
                  mapbox_zoom=10,
                  margin={"r":0,"t":0,"l":0,"b":0}
                 )

# %% [markdown]
# Here are the pathways of the routes extracted from the shapes dataframe

# %% [markdown]
# Now we are done with the datashader and route visualization.
#
# # Last exercise

# %%
#Create a list that stores the linestrings of pathways that intercept the stops in the 
# previus DataFrame 
points_with_linestr=[]
points=[]
for i in shapes["geometry"]:
    for k in pathways_7_8["geometry"]:
        if (i.distance(k)<1e-8) and i not in points_with_linestr:
            points.append(k)
           
            points_with_linestr.append(i)

# %%
# now we filter the shapes with these strings so it only contains the routes 
# that intercept the stops
shapes_intercept=shapes[shapes["geometry"].isin(points_with_linestr)]
shapes_intercept
# Out:
#      shape_id                                           geometry
# 2        0976  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 3        0977  LINESTRING (19.02519 47.50723, 19.02518 47.507...
# 77       2064  LINESTRING (19.07132 47.49604, 19.07127 47.496...
# 117      7404  LINESTRING (19.09142 47.47069, 19.09139 47.470...
# 126      A776  LINESTRING (19.00526 47.43212, 19.00518 47.432...
# ...       ...                                                ...
# 1292     Z255  LINESTRING (18.94023 47.45575, 18.94028 47.455...
# 1293     Z262  LINESTRING (19.01378 47.40563, 19.01375 47.405...
# 1295     Z545  LINESTRING (19.01851 47.46434, 19.01864 47.464...
# 1296     Z546  LINESTRING (18.92367 47.51776, 18.92387 47.517...
# 1297     Z895  LINESTRING (18.99852 47.49470, 18.99843 47.494...
#
# [371 rows x 2 columns]

# %%
#Now find the trips and from that the stops
trips_intercept=trips[trips["shape_id"].isin(shapes_intercept["shape_id"])]
stops_intercept=stop_times[stop_times["trip_id"].isin(trips_intercept["trip_id"])]
stops_intercept
# Out:
#              trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 15107   C34268105116  009220       25200.0         25200.0              0
# 15108   C34268105116  F02153       25320.0         25320.0              1
# 15109   C34268105116  F02225       25380.0         25380.0              2
# 15110   C34268105116  F01374       25500.0         25500.0              3
# 15111   C34268105116  F01380       25620.0         25620.0              4
# ...              ...     ...           ...             ...            ...
# 799978     C56119974  F02980       32580.0         32580.0              8
# 799979     C56119974  F02924       32700.0         32700.0              9
# 799980     C56119974  F02893       32760.0         32760.0             10
# 799981     C56119974  F02631       32880.0         32880.0             11
# 799982     C56119974  F02591       33000.0         33000.0             12
#
#                                  stop_headsign  pickup_type drop_off_type  \
# 15107                       Széll Kálmán tér M          NaN             1
# 15108                       Széll Kálmán tér M          NaN          None
# 15109                       Széll Kálmán tér M          NaN          None
# 15110                       Széll Kálmán tér M          NaN          None
# 15111                       Széll Kálmán tér M          NaN          None
# ...                                        ...          ...           ...
# 799978  KOCSISZÍNBE  Lehel u. / Róbert K. krt.          NaN          None
# 799979  KOCSISZÍNBE  Lehel u. / Róbert K. krt.          NaN          None
# 799980  KOCSISZÍNBE  Lehel u. / Róbert K. krt.          NaN          None
# 799981  KOCSISZÍNBE  Lehel u. / Róbert K. krt.          NaN          None
# 799982  KOCSISZÍNBE  Lehel u. / Róbert K. krt.          NaN          None
#
#         shape_dist_traveled route_id  ... direction_id  shape_id  \
# 15107                   0.0     3060  ...            1      B692
# 15108                 477.0     3060  ...            1      B692
# 15109                 960.0     3060  ...            1      B692
# 15110                1622.0     3060  ...            1      B692
# 15111                1942.0     3060  ...            1      B692
# ...                     ...      ...  ...          ...       ...
# 799978               4694.0     3014  ...            0      TI52
# 799979               5169.0     3014  ...            0      TI52
# 799980               5527.0     3014  ...            0      TI52
# 799981               6271.0     3014  ...            0      TI52
# 799982               6659.0     3014  ...            0      TI52
#
#                                 stop_name stop_code location_type  \
# 15107            Móricz Zsigmond körtér M      None           NaN
# 15108   Budafoki út / Karinthy Frigyes út      None           NaN
# 15109             Petőfi híd, budai hídfő      None           NaN
# 15110                       Boráros tér H      None           NaN
# 15111          Mester utca / Ferenc körút      None           NaN
# ...                                   ...       ...           ...
# 799978                   Ajtósi Dürer sor      None           NaN
# 799979   Erzsébet királyné útja, aluljáró      None           NaN
# 799980                  Kacsóh Pongrác út      None           NaN
# 799981  Vágány utca / Róbert Károly körút      None           NaN
# 799982   Lehel utca / Róbert Károly körút      None           NaN
#
#         location_sub_type parent_station wheelchair_boarding  stop_direction  \
# 15107                None           None                 1.0            None
# 15108                None           None                 1.0             114
# 15109                None           None                 1.0              54
# 15110                None           None                 2.0              54
# 15111                None           None                 1.0              14
# ...                   ...            ...                 ...             ...
# 799978               None           None                 1.0             -46
# 799979               None           None                 1.0             -49
# 799980               None           None                 1.0             -46
# 799981               None           None                 1.0             -46
# 799982               None           None                 2.0              18
#
#                          geometry
# 15107   POINT (19.04835 47.47750)
# 15108   POINT (19.05411 47.47583)
# 15109   POINT (19.05959 47.47693)
# 15110   POINT (19.06670 47.48038)
# 15111   POINT (19.06885 47.48275)
# ...                           ...
# 799978  POINT (19.09576 47.51381)
# 799979  POINT (19.09139 47.51681)
# 799980  POINT (19.08811 47.51906)
# 799981  POINT (19.08099 47.52362)
# 799982  POINT (19.07851 47.52624)
#
# [235622 rows x 21 columns]

# %%
#and we filter for time from 7:15-7:50 like before
stops_intercept_7_8=stops_intercept[stops_intercept["arrival_time"]<28200]
stops_intercept_7_8=stops_intercept_7_8[stops_intercept_7_8["arrival_time"]>26100]
#and add the short names
values_dict=dict(zip(routes["route_id"], routes["route_short_name"]))
short_names=[]
for i in stops_intercept_7_8["route_id"]:
    for k in values_dict:
        if i==k:
            short_names.append(values_dict[k])
stops_intercept_7_8["short_names"]=short_names
stops_intercept_7_8
# Out:
#              trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 15118   C34268105116  F01082       26220.0         26220.0             11
# 15119   C34268105116  F00933       26340.0         26340.0             12
# 15120   C34268105116  F00925       26460.0         26460.0             13
# 15121   C34268105116  F00141       26580.0         26580.0             14
# 15122   C34268105116  F00192       26640.0         26640.0             15
# ...              ...     ...           ...             ...            ...
# 799486      C5611982  008262       26280.0         26280.0             16
# 799487      C5611982  008148       26400.0         26400.0             17
# 799488      C5611982  008146       26460.0         26460.0             18
# 799489      C5611982  F01286       26580.0         26580.0             19
# 799536      C5611983  F01286       26160.0         26160.0             19
#
#              stop_headsign  pickup_type drop_off_type  shape_dist_traveled  \
# 15118   Széll Kálmán tér M          NaN          None               4773.0
# 15119   Széll Kálmán tér M          NaN          None               5454.0
# 15120   Széll Kálmán tér M          NaN          None               6141.0
# 15121   Széll Kálmán tér M          NaN          None               6621.0
# 15122   Széll Kálmán tér M          NaN          None               6953.0
# ...                    ...          ...           ...                  ...
# 799486          Népliget M          NaN          None               9379.0
# 799487          Népliget M          NaN          None               9955.0
# 799488          Népliget M          NaN          None              10529.0
# 799489          Népliget M          1.0          None              11223.0
# 799536          Népliget M          1.0          None              11223.0
#
#        route_id  ... shape_id                           stop_name stop_code  \
# 15118      3060  ...     B692                           Oktogon M      None
# 15119      3060  ...     B692                Nyugati pályaudvar M      None
# 15120      3060  ...     B692                     Jászai Mari tér      None
# 15121      3060  ...     B692           Margitsziget / Margit híd      None
# 15122      3060  ...     B692           Margit híd, budai hídfő H      None
# ...         ...  ...      ...                                 ...       ...
# 799486     3014  ...     TC22            Hidegkuti Nándor Stadion      None
# 799487     3014  ...     TC22  Kőbányai út / Könyves Kálmán körút      None
# 799488     3014  ...     TC22                    Vajda Péter utca      None
# 799489     3014  ...     TC22                          Népliget M      None
# 799536     3014  ...     TC22                          Népliget M      None
#
#        location_type location_sub_type  parent_station wheelchair_boarding  \
# 15118            NaN              None            None                 1.0
# 15119            NaN              None            None                 1.0
# 15120            NaN              None            None                 1.0
# 15121            NaN              None            None                 1.0
# 15122            NaN              None            None                 1.0
# ...              ...               ...             ...                 ...
# 799486           NaN              None            None                 1.0
# 799487           NaN              None            None                 1.0
# 799488           NaN              None            None                 1.0
# 799489           NaN              None            None                 1.0
# 799536           NaN              None            None                 1.0
#
#        stop_direction                   geometry short_names
# 15118             -43  POINT (19.06241 47.50594)           6
# 15119             -56  POINT (19.05617 47.51027)           6
# 15120             -67  POINT (19.04818 47.51310)           6
# 15121             -93  POINT (19.04252 47.51472)           6
# 15122             -92  POINT (19.03819 47.51462)           6
# ...               ...                        ...         ...
# 799486           -180  POINT (19.10891 47.49069)          1M
# 799487           -152  POINT (19.10708 47.48574)          1M
# 799488           -152  POINT (19.10317 47.48139)          1M
# 799489           -150  POINT (19.09891 47.47588)          1M
# 799536           -150  POINT (19.09891 47.47588)          1M
#
# [9554 rows x 22 columns]

# %%
stops_intercept_7_8["short_names"].unique()
# Out:
# array(['6', '4', '49', '138', '19', '250', '250B', '141', '139', '8E',
#        '58', '251A', '53', '153', '154', '296', '96', '59B', '114', '213',
#        '214', '101B', '101E', '150', '287', '13', '113A', '240', '196',
#        '196A', '88A', '40', '40B', '88', '40E', '277', '2', '272', '172',
#        '173', '133E', '188E', '158', '191', '291', '91', '107', '20E',
#        '46', '146', '187', '87', '112', '110', '110E', '178', '105',
#        '130', '212B', '212A', '212', '33', '1', '51A', '108E', '7', '102',
#        '17', '7E', '5', '30', '30A', '140A', '140', '221', '21A', '21',
#        '1M'], dtype=object)

# %%
#now we extract the stops that intercept the routes in the stops_intercept_7_8 Dataframe
stops_rendes=stops_intercept_7_8[stops_intercept_7_8["geometry"].isin(points)]
stops_rendes
# Out:
#              trip_id stop_id  arrival_time  departure_time  stop_sequence  \
# 15123   C34268105116  F00198       26760.0         26760.0             16
# 15126   C34268106997  009220       26400.0         26400.0              0
# 15128   C34268106997  F02225       26580.0         26580.0              2
# 15142   C34268106997  F00198       27960.0         27960.0             16
# 17506    C3426814107  009220       27360.0         27360.0              0
# ...              ...     ...           ...             ...            ...
# 799320      C5611967  F01322       26880.0         26880.0             14
# 799322      C5611967  008262       27060.0         27060.0             16
# 799340      C5611968  F01322       26520.0         26520.0             14
# 799342      C5611968  008262       26700.0         26700.0             16
# 799486      C5611982  008262       26280.0         26280.0             16
#
#              stop_headsign  pickup_type drop_off_type  shape_dist_traveled  \
# 15123   Széll Kálmán tér M          NaN          None               7695.0
# 15126   Széll Kálmán tér M          NaN             1                  0.0
# 15128   Széll Kálmán tér M          NaN          None                960.0
# 15142   Széll Kálmán tér M          NaN          None               7695.0
# 17506   Széll Kálmán tér M          NaN             1                  0.0
# ...                    ...          ...           ...                  ...
# 799320          Népliget M          NaN          None               8290.0
# 799322          Népliget M          NaN          None               9379.0
# 799340          Népliget M          NaN          None               8290.0
# 799342          Népliget M          NaN          None               9379.0
# 799486          Népliget M          NaN          None               9379.0
#
#        route_id  ... shape_id                 stop_name stop_code  \
# 15123      3060  ...     B692            Mechwart liget      None
# 15126      3060  ...     B692  Móricz Zsigmond körtér M      None
# 15128      3060  ...     B692   Petőfi híd, budai hídfő      None
# 15142      3060  ...     B692            Mechwart liget      None
# 17506      3060  ...     B692  Móricz Zsigmond körtér M      None
# ...         ...  ...      ...                       ...       ...
# 799320     3014  ...     TC22   Puskás Ferenc Stadion M      None
# 799322     3014  ...     TC22  Hidegkuti Nándor Stadion      None
# 799340     3014  ...     TC22   Puskás Ferenc Stadion M      None
# 799342     3014  ...     TC22  Hidegkuti Nándor Stadion      None
# 799486     3014  ...     TC22  Hidegkuti Nándor Stadion      None
#
#        location_type location_sub_type  parent_station wheelchair_boarding  \
# 15123            NaN              None            None                 1.0
# 15126            NaN              None            None                 1.0
# 15128            NaN              None            None                 1.0
# 15142            NaN              None            None                 1.0
# 17506            NaN              None            None                 1.0
# ...              ...               ...             ...                 ...
# 799320           NaN              None            None                 1.0
# 799322           NaN              None            None                 1.0
# 799340           NaN              None            None                 1.0
# 799342           NaN              None            None                 1.0
# 799486           NaN              None            None                 1.0
#
#        stop_direction                   geometry short_names
# 15123            -119  POINT (19.03146 47.51078)           6
# 15126            None  POINT (19.04835 47.47750)           6
# 15128              54  POINT (19.05959 47.47693)           6
# 15142            -119  POINT (19.03146 47.51078)           6
# 17506            None  POINT (19.04835 47.47750)           6
# ...               ...                        ...         ...
# 799320            170  POINT (19.10815 47.50039)          1M
# 799322           -180  POINT (19.10891 47.49069)          1M
# 799340            170  POINT (19.10815 47.50039)          1M
# 799342           -180  POINT (19.10891 47.49069)          1M
# 799486           -180  POINT (19.10891 47.49069)          1M
#
# [1563 rows x 22 columns]

# %%
#and these are the stops
stops_rendes["stop_name"].unique()
# Out:
# array(['Mechwart liget', 'Móricz Zsigmond körtér M',
#        'Petőfi híd, budai hídfő', 'Újbuda-központ M',
#        'Margit híd, budai hídfő H', 'Széna tér', 'Széll Kálmán tér M',
#        'Kosztolányi Dezső tér', 'Lépcsős utca', 'Jókai Mór utca',
#        'Őrmezei út', 'Kelenföld vasútállomás M',
#        'Leányka utcai lakótelep', 'Városház tér',
#        'Zelk Zoltán út (Menyecske utca)', 'Gazdagréti út',
#        'Jégvirág utca', 'Dayka Gábor utca', 'Gazdagréti tér',
#        'Nagyszeben út', 'Március 15. tér', 'Astoria M', 'Sasadi út',
#        'Tisza István tér', 'Zugló vasútállomás', 'Keleti pályaudvar M',
#        'Blaha Lujza tér M', 'Uránia', 'Újpalota, Nyírpalota út',
#        'Vásárcsarnok', 'Molnár Viktor utca', 'Bosnyák tér', 'Fő tér',
#        'Bikás park M', 'Karolina út', 'Duránci utca',
#        'Infopark (Pázmány Péter sétány)', 'Andor utca / Tétényi út',
#        'Egyetemváros - A38 hajóállomás', 'Budafoki út / Dombóvári út',
#        'Kiss János altábornagy utca',
#        'Budatétény vasútállomás (Növény utca)',
#        'Angeli utca / Nagytétényi út', 'Budaörsi út / Villányi út',
#        'Miskolci utca / Csömöri út', 'Mester utca / Könyves Kálmán körút',
#        'Budafoki út / Szerémi sor', 'Kelenföldi Erőmű',
#        'Nagytétény, Erdélyi utca', 'Szent Orbán tér', 'Pethényi út',
#        'Boráros tér H', 'Városkút', 'Svábhegy', 'Bécsi út / Vörösvári út',
#        'Lehel utca / Róbert Károly körút', 'Hidegkuti Nándor Stadion',
#        'Népliget M', 'Puskás Ferenc Stadion M',
#        'Ferencváros vá. - Málenkij Robot Eh.', 'Etele út / Fehérvári út',
#        'Göncz Árpád városközpont M', 'Óbudai rendelőintézet',
#        'Bártfai utca'], dtype=object)

# %%
my=dict(zip(stops_intercept_7_8["trip_id"],stops_intercept_7_8["short_names"]))
temp=[]
res={}
for i,k in my.items():
    if k not in temp:
        temp.append(k)
        res[i]=k
res
# Out:
# {'C34268105116': '6',
#  'C342681730': '4',
#  'C3635065': '49',
#  'C3800224': '138',
#  'C45939101': '19',
#  'C46206404': '250',
#  'C46206410': '250B',
#  'C46470428': '141',
#  'C47110102': '139',
#  'C48289101': '8E',
#  'C4951840': '58',
#  'C5048315': '251A',
#  'C5052049': '53',
#  'C50522133': '153',
#  'C50522192': '154',
#  'C5104028': '296',
#  'C5104047': '96',
#  'C513071031': '59B',
#  'C514521399': '114',
#  'C51452174': '213',
#  'C51452202': '214',
#  'C51579111': '101B',
#  'C51579116': '101E',
#  'C51744101': '150',
#  'C5239418': '287',
#  'C5241641': '13',
#  'C5241647': '113A',
#  'C5265328': '240',
#  'C52683115': '196',
#  'C52683128': '196A',
#  'C529511001': '88A',
#  'C529511006': '40',
#  'C529511011': '40B',
#  'C52951118': '88',
#  'C529512660': '40E',
#  'C5377220': '277',
#  'C53823221J': '2',
#  'C539901128': '272',
#  'C5399011948': '172',
#  'C539902658': '173',
#  'C54015135': '133E',
#  'C5411439': '188E',
#  'C54153144': '158',
#  'C541541279': '191',
#  'C544891275': '291',
#  'C544891280': '91',
#  'C5450110': '107',
#  'C54505176': '20E',
#  'C54530103': '46',
#  'C5453085': '146',
#  'C5458629': '187',
#  'C5458637': '87',
#  'C54589105': '112',
#  'C54589129': '110',
#  'C54589153': '110E',
#  'C54621124': '178',
#  'C54621130': '105',
#  'C5465922': '130',
#  'C547346611': '212B',
#  'C547346617': '212A',
#  'C547346629': '212',
#  'C5474657': '33',
#  'C5478717591': '1',
#  'C54854119': '51A',
#  'C5486312': '108E',
#  'C54869147': '7',
#  'C5489637': '102',
#  'C54943114': '17',
#  'C5510746': '7E',
#  'C552751412': '5',
#  'C5531540': '30',
#  'C5531556': '30A',
#  'C55471119': '140A',
#  'C55471147': '140',
#  'C559858827': '221',
#  'C559858847': '21A',
#  'C559858852': '21',
#  'C5611917': '1M'}

# %%
intercept_one=stops_intercept_7_8[stops_intercept_7_8["trip_id"].isin(res.keys())]
intercept_one.reset_index(inplace=True)
intercept_one
# Out:
#       index       trip_id stop_id  arrival_time  departure_time  \
# 0     15118  C34268105116  F01082       26220.0         26220.0
# 1     15119  C34268105116  F00933       26340.0         26340.0
# 2     15120  C34268105116  F00925       26460.0         26460.0
# 3     15121  C34268105116  F00141       26580.0         26580.0
# 4     15122  C34268105116  F00192       26640.0         26640.0
# ..      ...           ...     ...           ...             ...
# 774  788115    C559858852  110321       27240.0         27240.0
# 775  797542      C5611917  F00626       26160.0         26160.0
# 776  797543      C5611917  F00614       26280.0         26280.0
# 777  797544      C5611917  F00586       26340.0         26340.0
# 778  797545      C5611917  F00569       26460.0         26460.0
#
#      stop_sequence            stop_headsign  pickup_type drop_off_type  \
# 0               11       Széll Kálmán tér M          NaN          None
# 1               12       Széll Kálmán tér M          NaN          None
# 2               13       Széll Kálmán tér M          NaN          None
# 3               14       Széll Kálmán tér M          NaN          None
# 4               15       Széll Kálmán tér M          NaN          None
# ..             ...                      ...          ...           ...
# 774             16                  Normafa          1.0          None
# 775             16  Bécsi út / Vörösvári út          NaN          None
# 776             17  Bécsi út / Vörösvári út          NaN          None
# 777             18  Bécsi út / Vörösvári út          NaN          None
# 778             19  Bécsi út / Vörösvári út          NaN          None
#
#      shape_dist_traveled  ... shape_id                  stop_name  stop_code  \
# 0                 4773.0  ...     B692                  Oktogon M       None
# 1                 5454.0  ...     B692       Nyugati pályaudvar M       None
# 2                 6141.0  ...     B692            Jászai Mari tér       None
# 3                 6621.0  ...     B692  Margitsziget / Margit híd       None
# 4                 6953.0  ...     B692  Margit híd, budai hídfő H       None
# ..                   ...  ...      ...                        ...        ...
# 774               6999.0  ...     XD12   Normafa, látogatóközpont       None
# 775               9595.0  ...     TC21           Szentlélek tér H       None
# 776              10061.0  ...     TC21                Flórián tér       None
# 777              10760.0  ...     TC21      Óbudai rendelőintézet       None
# 778              11204.0  ...     TC21    Bécsi út / Vörösvári út       None
#
#     location_type location_sub_type parent_station  wheelchair_boarding  \
# 0             NaN              None           None                  1.0
# 1             NaN              None           None                  1.0
# 2             NaN              None           None                  1.0
# 3             NaN              None           None                  1.0
# 4             NaN              None           None                  1.0
# ..            ...               ...            ...                  ...
# 774           NaN              None           None                  1.0
# 775           NaN              None           None                  1.0
# 776           NaN              None           None                  1.0
# 777           NaN              None           None                  1.0
# 778           NaN              None           None                  1.0
#
#     stop_direction                   geometry  short_names
# 0              -43  POINT (19.06241 47.50594)            6
# 1              -56  POINT (19.05617 47.51027)            6
# 2              -67  POINT (19.04818 47.51310)            6
# 3              -93  POINT (19.04252 47.51472)            6
# 4              -92  POINT (19.03819 47.51462)            6
# ..             ...                        ...          ...
# 774            -76  POINT (18.96744 47.50074)           21
# 775            -73  POINT (19.04521 47.53959)           1M
# 776            -50  POINT (19.03996 47.54152)           1M
# 777            -42  POINT (19.03346 47.54596)           1M
# 778           None  POINT (19.02937 47.54877)           1M
#
# [779 rows x 23 columns]

# %%
for_loop=intercept_one["short_names"].unique()
for_loop
# Out:
# array(['6', '4', '49', '138', '19', '250', '250B', '141', '139', '8E',
#        '58', '251A', '53', '153', '154', '296', '96', '59B', '114', '213',
#        '214', '101B', '101E', '150', '287', '13', '113A', '240', '196',
#        '196A', '88A', '40', '40B', '88', '40E', '277', '2', '272', '172',
#        '173', '133E', '188E', '158', '191', '291', '91', '107', '20E',
#        '46', '146', '187', '87', '112', '110', '110E', '178', '105',
#        '130', '212B', '212A', '212', '33', '1', '51A', '108E', '7', '102',
#        '17', '7E', '5', '30', '30A', '140A', '140', '221', '21A', '21',
#        '1M'], dtype=object)

# %%
time_from_origin=[]
bad_trip_ids=[]
stoppyka=stops_rendes["stop_name"].unique()
for i in for_loop:
    route=intercept_one[intercept_one["short_names"]==i]
    dep_time=list(route[route["stop_name"].isin(stoppyka)]["departure_time"])
    if len(dep_time)==0:
        route.reset_index(inplace=True)
        bad_trip_ids.append(route["trip_id"][0])
    else:
        time_from_origin.append(route["departure_time"].apply(lambda x: abs(x-dep_time[0])))

# %%
#and extracting the times from the time_from origin list so we can append it to the pathways_one
times=[]
for i in time_from_origin:
    for k in i:
        times.append(k)

# %%
intercept_one=intercept_one[~intercept_one["trip_id"].isin(bad_trip_ids)]
intercept_one.reset_index(inplace=True)

# %%
intercept_one["times"]=times

# %%
intercept_one["short_names"].unique()
# Out:
# array(['6', '4', '49', '138', '19', '250', '250B', '141', '139', '8E',
#        '251A', '53', '153', '154', '296', '96', '114', '213', '214',
#        '101B', '101E', '150', '13', '113A', '196', '88A', '40', '40B',
#        '88', '40E', '2', '272', '172', '173', '133E', '188E', '158',
#        '191', '91', '107', '20E', '46', '187', '110', '110E', '105',
#        '130', '212A', '212', '33', '1', '51A', '108E', '7', '17', '7E',
#        '5', '140A', '21A', '21', '1M'], dtype=object)

# %% [markdown]
# # Visualizing the routes

# %%
stop_short=routes.merge(trips, left_on=["route_id"], right_on=["route_id"], how="right")
stop_short_dict=dict(zip(stop_short["shape_id"],stop_short["route_short_name"]))

# %%
trips_intercept=trips[trips["trip_id"].isin(intercept_one["trip_id"])]
shapes_intercept=shapes[shapes["shape_id"].isin(trips_intercept["shape_id"])]
shapes_intercept
# Out:
#      shape_id                                           geometry
# 2        0976  LINESTRING (19.04686 47.47404, 19.04688 47.474...
# 117      7404  LINESTRING (19.09142 47.47069, 19.09139 47.470...
# 126      A776  LINESTRING (19.00526 47.43212, 19.00518 47.432...
# 131      AC06  LINESTRING (19.04847 47.47404, 19.04844 47.473...
# 136      AH19  LINESTRING (19.06299 47.46985, 19.06299 47.469...
# ...       ...                                                ...
# 1216     XJ38  LINESTRING (19.06600 47.60261, 19.06602 47.602...
# 1224     XM91  LINESTRING (18.99158 47.40444, 18.99153 47.404...
# 1225     XN76  LINESTRING (19.08235 47.58266, 19.08238 47.582...
# 1280     Y219  LINESTRING (19.05518 47.49744, 19.05562 47.497...
# 1291     Z084  LINESTRING (19.14204 47.54704, 19.14223 47.546...
#
# [61 rows x 2 columns]

# %%
short_names=[]
for i in shapes_intercept["shape_id"]:
    for k in stop_short_dict:
        if i==k:
            short_names.append(stop_short_dict[k])

shapes_intercept["short_names"]=short_names

# %%
shapes_intercept["short_names"]
# Out:
# 2         4
# 117       2
# 126     158
# 131     150
# 136     153
#        ...
# 1216    296
# 1224    213
# 1225    196
# 1280     49
# 1291     7E
# Name: short_names, Length: 61, dtype: object

# %%
import shapely
lats = []
lons = []
names = []

for feature, name in zip(shapes_intercept.geometry, shapes_intercept["short_names"]):
    if isinstance(feature, shapely.geometry.linestring.LineString):
        linestrings = [feature]
    elif isinstance(feature, shapely.geometry.multilinestring.MultiLineString):
        linestrings = feature.geoms
    else:
        continue
    for linestring in linestrings:
        x, y = linestring.xy
        lats = np.append(lats, y)
        lons = np.append(lons, x)
        names = np.append(names, [name]*len(y))
        lats = np.append(lats, None)
        lons = np.append(lons, None)
        names = np.append(names, None)

fig = px.line_mapbox(lat=lats, lon=lons, hover_name=names)

fig.add_trace(go.Scattermapbox(
        lat=[47.47277215114886],
        lon=[19.060034103922074],
        marker=go.scattermapbox.Marker(
            size=10,
            color='rgb(0, 144, 144)',
            opacity=0.7
        ),
        text=["BME I Epulet"],))

fig.update_layout(mapbox_style="carto-darkmatter",
                  mapbox_zoom=10,
                  margin={"r":0,"t":0,"l":0,"b":0}
                 )
